# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Day 4 — Mini Automation: Clean & Export Reports\n",
    "\n",
    "This notebook demonstrates a small, production-friendly cleaning pipeline using **pandas**, creates export-ready reports (CSV), and produces a quick verification visualization. Use this as a template to apply on real CSVs.\n",
    "\n",
    "Files this notebook will create (in `reports/day4/`):\n",
    "- `sales_by_region.csv`\n",
    "- `top_customers_by_sales.csv`\n",
    "- `monthly_summary.csv`\n",
    "\n",
    "Run each cell sequentially."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Imports\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "from pathlib import Path\n",
    "import matplotlib.pyplot as plt\n",
    "%matplotlib inline\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1) Create a messy in-memory dataset (or replace with `pd.read_csv()` to load a file)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "raw = {\n",
    "    \"order_id\": [1011, 1021, 1033, 1054, 1066, 1077, 1088],\n",
    "    \"customer_id\": [11, 21, 33, 54, 11, 21, 33],\n",
    "    \"region\": [\" Pune \", \"Mumbai\", \"nagpur\", \"Nashik\", None, \"Mumbai\", \"Nagpur\"],\n",
    "    \"amount\": [\"25,000\", \"15000\", \"28,000\", \"52000\", \"12,000\", None, \" 30,000 \"],\n",
    "    \"order_date\": [\"2025-03-11\", \"2025/05/03\", \"2025-04-01\", \"2025-08-12\", \"2025-09-10\", \"2025-09-15\", \"2025-09-20\"]\n",
    "}\n",
    "df_raw = pd.DataFrame(raw)\n",
    "df_raw.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2) Cleaning pipeline (function) — modular and reusable"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "def clean_sales_df(df: pd.DataFrame) -> pd.DataFrame:\n",
    "    df = df.copy()\n",
    "    # Standardize whitespace and case\n",
    "    df['region'] = df['region'].astype(str).str.strip().replace({'None': None})\n",
    "    df['region'] = df['region'].replace('nan', None)\n",
    "    # Clean amount: remove commas/spaces and coerce\n",
    "    df['amount'] = df['amount'].astype(str).str.replace(',', '').str.strip()\n",
    "    df['amount'] = pd.to_numeric(df['amount'], errors='coerce')\n",
    "    # Parse dates\n",
    "    df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')\n",
    "    # Fill missing values sensibly\n",
    "    df['region'] = df['region'].fillna('Unknown')\n",
    "    df['amount'] = df['amount'].fillna(0).astype(int)\n",
    "    # Drop rows with invalid dates (or optionally handle them)\n",
    "    df = df.dropna(subset=['order_date'])\n",
    "    df = df[['order_id', 'customer_id', 'region', 'amount', 'order_date']]\n",
    "    return df\n",
    "\n",
    "# Run cleaning\n",
    "df = clean_sales_df(df_raw)\n",
    "df"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3) Create exportable reports"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "def create_reports(df: pd.DataFrame, out_dir: Path):\n",
    "    out_dir.mkdir(parents=True, exist_ok=True)\n",
    "    # Sales by region\n",
    "    sales_region = df.groupby('region', as_index=False)['amount'].sum().rename(columns={'amount': 'total_sales'})\n",
    "    sales_region = sales_region.sort_values('total_sales', ascending=False)\n",
    "    sales_region.to_csv(out_dir / \"sales_by_region.csv\", index=False)\n",
    "    # Top customers\n",
    "    top_customers = df.groupby('customer_id', as_index=False)['amount'].sum().rename(columns={'amount': 'total_spent'})\n",
    "    top_customers = top_customers.sort_values('total_spent', ascending=False)\n",
    "    top_customers.to_csv(out_dir / \"top_customers_by_sales.csv\", index=False)\n",
    "    # Monthly summary\n",
    "    df['order_month'] = df['order_date'].dt.to_period('M')\n",
    "    monthly = df.groupby('order_month')['amount'].agg(['sum','mean','count']).reset_index()\n",
    "    monthly.to_csv(out_dir / \"monthly_summary.csv\", index=False)\n",
    "    return sales_region, top_customers, monthly\n",
    "\n",
    "out_dir = Path('reports/day4')\n",
    "sales_region, top_customers, monthly = create_reports(df, out_dir)\n",
    "print('Reports saved to', out_dir.resolve())\n",
    "sales_region, top_customers.head(), monthly"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4) Quick visualization to validate output"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plt.figure(figsize=(7,4))\n",
    "plt.bar(sales_region['region'], sales_region['total_sales'])\n",
    "plt.title('Sales by Region')\n",
    "plt.ylabel('Total Sales (₹)')\n",
    "plt.xlabel('Region')\n",
    "plt.xticks(rotation=30)\n",
    "plt.grid(axis='y', linestyle='--', alpha=0.4)\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5) Optional: package into a small CLI function (example)\n",
    "\n",
    "You can wrap this pipeline in a function to run nightly (cron/Task Scheduler) or trigger from a small command-line interface."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "def run_pipeline(source_df=None, save_reports=True, out_dir=Path('reports/day4')):\n",
    "    if source_df is None:\n",
    "        source_df = df_raw\n",
    "    cleaned = clean_sales_df(source_df)\n",
    "    sales_region, top_customers, monthly = create_reports(cleaned, Path(out_dir))\n",
    "    return {'cleaned': cleaned, 'sales_region': sales_region, 'top_customers': top_customers, 'monthly': monthly}\n",
    "\n",
    "# Example run\n",
    "res = run_pipeline()\n",
    "res['sales_region']"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Save and commit\n",
    "\n",
    "Files generated by this notebook are in `reports/day4/`. Add them to your repo if you'd like to store the generated CSVs as artifacts."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Day 4 — Mini Automation: Clean & Export Reports\n",
#       8     "\n",
#       9     "This notebook demonstrates a small, production-friendly cleaning pipeline using **pandas**, creates export-ready reports (CSV), and produces a quick verification visualization. Use this as a template to apply on real CSVs.\n",
#      10     "\n",
#      11     "Files this notebook will create (in `reports/day4/`):\n",
#      12     "- `sales_by_region.csv`\n",
#      13     "- `top_customers_by_sales.csv`\n",
#      14     "- `monthly_summary.csv`\n",
#      15     "\n",
#      16     "Run each cell sequentially."
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "code",
# ---> 21    "execution_count": null,
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "# Imports\n",
#      26     "import pandas as pd\n",
#      27     "import numpy as np\n",
#      28     "from pathlib import Path\n",
#      29     "import matplotlib.pyplot as plt\n",
#      30     "%matplotlib inline\n"
#      31    ]
#      32   },
#      33   {
#      34    "cell_type": "markdown",
#      35    "metadata": {},
#      36    "source": [
#      37     "## 1) Create a messy in-memory dataset (or replace with `pd.read_csv()` to load a file)"
#      38    ]
#      39   },
#      40   {
#      41    "cell_type": "code",
#      42    "execution_count": null,
#      43    "metadata": {},
#      44    "outputs": [],
#      45    "source": [
#      46     "raw = {\n",
#      47     "    \"order_id\": [1011, 1021, 1033, 1054, 1066, 1077, 1088],\n",
#      48     "    \"customer_id\": [11, 21, 33, 54, 11, 21, 33],\n",
#      49     "    \"region\": [\" Pune \", \"Mumbai\", \"nagpur\", \"Nashik\", None, \"Mumbai\", \"Nagpur\"],\n",
#      50     "    \"amount\": [\"25,000\", \"15000\", \"28,000\", \"52000\", \"12,000\", None, \" 30,000 \"],\n",
#      51     "    \"order_date\": [\"2025-03-11\", \"2025/05/03\", \"2025-04-01\", \"2025-08-12\", \"2025-09-10\", \"2025-09-15\", \"2025-09-20\"]\n",
#      52     "}\n",
#      53     "df_raw = pd.DataFrame(raw)\n",
#      54     "df_raw.head()"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "markdown",
#      59    "metadata": {},
#      60    "source": [
#      61     "## 2) Cleaning pipeline (function) — modular and reusable"
#      62    ]
#      63   },
#      64   {
#      65    "cell_type": "code",
#      66    "execution_count": null,
#      67    "metadata": {},
#      68    "outputs": [],
#      69    "source": [
#      70     "def clean_sales_df(df: pd.DataFrame) -> pd.DataFrame:\n",
#      71     "    df = df.copy()\n",
#      72     "    # Standardize whitespace and case\n",
#      73     "    df['region'] = df['region'].astype(str).str.strip().replace({'None': None})\n",
#      74     "    df['region'] = df['region'].replace('nan', None)\n",
#      75     "    # Clean amount: remove commas/spaces and coerce\n",
#      76     "    df['amount'] = df['amount'].astype(str).str.replace(',', '').str.strip()\n",
#      77     "    df['amount'] = pd.to_numeric(df['amount'], errors='coerce')\n",
#      78     "    # Parse dates\n",
#      79     "    df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')\n",
#      80     "    # Fill missing values sensibly\n",
#      81     "    df['region'] = df['region'].fillna('Unknown')\n",
#      82     "    df['amount'] = df['amount'].fillna(0).astype(int)\n",
#      83     "    # Drop rows with invalid dates (or optionally handle them)\n",
#      84     "    df = df.dropna(subset=['order_date'])\n",
#      85     "    df = df[['order_id', 'customer_id', 'region', 'amount', 'order_date']]\n",
#      86     "    return df\n",
#      87     "\n",
#      88     "# Run cleaning\n",
#      89     "df = clean_sales_df(df_raw)\n",
#      90     "df"
#      91    ]
#      92   },
#      93   {
#      94    "cell_type": "markdown",
#      95    "metadata": {},
#      96    "source": [
#      97     "## 3) Create exportable reports"
#      98    ]
#      99   },
#     100   {
#     101    "cell_type": "code",
#     102    "execution_count": null,
#     103    "metadata": {},
#     104    "outputs": [],
#     105    "source": [
#     106     "def create_reports(df: pd.DataFrame, out_dir: Path):\n",
#     107     "    out_dir.mkdir(parents=True, exist_ok=True)\n",
#     108     "    # Sales by region\n",
#     109     "    sales_region = df.groupby('region', as_index=False)['amount'].sum().rename(columns={'amount': 'total_sales'})\n",
#     110     "    sales_region = sales_region.sort_values('total_sales', ascending=False)\n",
#     111     "    sales_region.to_csv(out_dir / \"sales_by_region.csv\", index=False)\n",
#     112     "    # Top customers\n",
#     113     "    top_customers = df.groupby('customer_id', as_index=False)['amount'].sum().rename(columns={'amount': 'total_spent'})\n",
#     114     "    top_customers = top_customers.sort_values('total_spent', ascending=False)\n",
#     115     "    top_customers.to_csv(out_dir / \"top_customers_by_sales.csv\", index=False)\n",
#     116     "    # Monthly summary\n",
#     117     "    df['order_month'] = df['order_date'].dt.to_period('M')\n",
#     118     "    monthly = df.groupby('order_month')['amount'].agg(['sum','mean','count']).reset_index()\n",
#     119     "    monthly.to_csv(out_dir / \"monthly_summary.csv\", index=False)\n",
#     120     "    return sales_region, top_customers, monthly\n",
#     121     "\n",
#     122     "out_dir = Path('reports/day4')\n",
#     123     "sales_region, top_customers, monthly = create_reports(df, out_dir)\n",
#     124     "print('Reports saved to', out_dir.resolve())\n",
#     125     "sales_region, top_customers.head(), monthly"
#     126    ]
#     127   },
#     128   {
#     129    "cell_type": "markdown",
#     130    "metadata": {},
#     131    "source": [
#     132     "## 4) Quick visualization to validate output"
#     133    ]
#     134   },
#     135   {
#     136    "cell_type": "code",
#     137    "execution_count": null,
#     138    "metadata": {},
#     139    "outputs": [],
#     140    "source": [
#     141     "plt.figure(figsize=(7,4))\n",
#     142     "plt.bar(sales_region['region'], sales_region['total_sales'])\n",
#     143     "plt.title('Sales by Region')\n",
#     144     "plt.ylabel('Total Sales (₹)')\n",
#     145     "plt.xlabel('Region')\n",
#     146     "plt.xticks(rotation=30)\n",
#     147     "plt.grid(axis='y', linestyle='--', alpha=0.4)\n",
#     148     "plt.tight_layout()\n",
#     149     "plt.show()"
#     150    ]
#     151   },
#     152   {
#     153    "cell_type": "markdown",
#     154    "metadata": {},
#     155    "source": [
#     156     "## 5) Optional: package into a small CLI function (example)\n",
#     157     "\n",
#     158     "You can wrap this pipeline in a function to run nightly (cron/Task Scheduler) or trigger from a small command-line interface."
#     159    ]
#     160   },
#     161   {
#     162    "cell_type": "code",
#     163    "execution_count": null,
#     164    "metadata": {},
#     165    "outputs": [],
#     166    "source": [
#     167     "def run_pipeline(source_df=None, save_reports=True, out_dir=Path('reports/day4')):\n",
#     168     "    if source_df is None:\n",
#     169     "        source_df = df_raw\n",
#     170     "    cleaned = clean_sales_df(source_df)\n",
#     171     "    sales_region, top_customers, monthly = create_reports(cleaned, Path(out_dir))\n",
#     172     "    return {'cleaned': cleaned, 'sales_region': sales_region, 'top_customers': top_customers, 'monthly': monthly}\n",
#     173     "\n",
#     174     "# Example run\n",
#     175     "res = run_pipeline()\n",
#     176     "res['sales_region']"
#     177    ]
#     178   },
#     179   {
#     180    "cell_type": "markdown",
#     181    "metadata": {},
#     182    "source": [
#     183     "## Save and commit\n",
#     184     "\n",
#     185     "Files generated by this notebook are in `reports/day4/`. Add them to your repo if you'd like to store the generated CSVs as artifacts."
#     186    ]
#     187   }
#     188  ],
#     189  "metadata": {
#     190   "kernelspec": {
#     191    "display_name": "Python 3",
#     192    "language": "python",
#     193    "name": "python3"
#     194   },
#     195   "language_info": {
#     196    "name": "python",
#     197    "version": "3.10"
#     198   }
#     199  },
#     200  "nbformat": 4,
#     201  "nbformat_minor": 5
#     202 }
#
# NameError: name 'null' is not defined
